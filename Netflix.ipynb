# %%
import json

dic={
    'Emp1':{'Name':'Vengatesh', 'Degree':'B.Tech'},
    'Emp2':{'Name':'Prasanth','Degree':'B.E'},
    'Emp3':{'Name':'Lokesh','Degree':'M.E'}
}
file = open('Emp.json','w')
json.dump(dic,file,indent=6)
file.close()

# %%
import json
import numpy as np
import pandas as pd

netflix = pd.read_csv('data_netflix.csv')
netflix
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
netflix.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
netflix.tail()
# Out:
#        show_id     type                                        title director  \
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 6231                                                NaN             NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#      date_added  release_year rating    duration  \
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
netflix.index
# Out:
# RangeIndex(start=0, stop=6234, step=1)

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.loc[20:30]
# Out:
#      show_id     type               title                     director  \
# 20  80060297    Movie   Manhattan Romance                  Tom O'Brien
# 21  80046728    Movie         Moonwalkers       Antoine Bardou-Jacquet
# 22  80046727    Movie      Rolling Papers                Mitch Dickman
# 23  70304988    Movie  Stonehearst Asylum                Brad Anderson
# 24  80057700    Movie          The Runner                 Austin Stark
# 25  80045922    Movie             6 Years                Hannah Fidell
# 26  80244601  TV Show     Castle of Stars                          NaN
# 27  80203094    Movie         City of Joy              Madeleine Gavin
# 28  80190843  TV Show      First and Last                          NaN
# 29  70241607    Movie           Laddaland             Sopon Sukdapisit
# 30  80988892    Movie            Next Gen  Kevin R. Adams, Joe Ksander
#
#                                                  cast  \
# 20  Tom O'Brien, Katherine Waterston, Caitlin Fitz...
# ...

# %%
netflix.iloc[120]
# Out:
# show_id                                                  81186757
# type                                                        Movie
# title                                            Oh! Baby (Tamil)
# director                                      B. V. Nandini Reddy
# cast            Samantha Ruth Prabhu, Lakshmi, Rajendraprasad,...
# country                                                     India
# date_added                                     September 25, 2019
# release_year                                                 2019
# rating                                                      TV-14
# duration                                                  146 min
# listed_in        Comedies, International Movies, Music & Musicals
# description     A surly septuagenarian gets another chance at ...
# Name: 120, dtype: object

# %%
netflix['release_year'].min()
# Out:
# 1925

# %%
netflix['release_year'].idxmin()
# Out:
# 4292

# %%
netflix.iloc[4292]
# Out:
# show_id                                                  81030762
# type                                                      TV Show
# title                           Pioneers: First Women Filmmakers*
# director                                                      NaN
# cast                                                          NaN
# country                                                       NaN
# date_added                                      December 30, 2018
# release_year                                                 1925
# rating                                                      TV-PG
# duration                                                 1 Season
# listed_in                                                TV Shows
# description     This collection restores films from women who ...
# Name: 4292, dtype: object

# %%
netflix['release_year'].max()
# Out:
# 2020

# %%
netflix['release_year'].idxmax()
# Out:
# 1315

# %%
netflix.iloc[1315]
# Out:
# show_id                                                  81034946
# type                                                      TV Show
# title                                          Maradona in Mexico
# director                                                      NaN
# cast                                       Diego Armando Maradona
# country                          Argentina, United States, Mexico
# date_added                                      November 13, 2019
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                 1 Season
# listed_in                   Docuseries, Spanish-Language TV Shows
# description     In this docuseries, soccer great Diego Maradon...
# Name: 1315, dtype: object

# %%
#cleaning the dataset
#to remove the nan value from the dataset

netflix.dropna('country',axis=1)
# Out:
# C:\Users\VENGATESH\AppData\Local\Temp\ipykernel_13704\3141987123.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   netflix.dropna('country',axis=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 #cleaning the dataset
#       2 #to remove the nan value from the dataset
# ----> 4 netflix.dropna('country',axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
size=len(netflix['title'])
size
# Out:
# 6234

# %%
netflix.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False      True  False    False       False
# 3       False  False  False      True  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 6229    False  False  False      True  False    False        True
# 6230    False  False  False      True  False    False        True
# 6231    False  False  False      True   True     True        True
# 6232    False  False  False      True  False    False        True
# 6233    False  False  False      True  False    False        True
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
IMDB=np.random.uniform(low=0,high=10,size=len(netflix['title']))
IMDB=np.

# %%
netflix['IMDB rating']=IMDB

# %%
netflix
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
netflix.sort_values(by='IMDB rating',ascending=False)
# Out:
#        show_id     type                                              title  \
# 1101  80216094  TV Show          Bumping Mics with Jeff Ross & Dave Attell
# 5631  70279852  TV Show                    Marvel's Agents of S.H.I.E.L.D.
# 1552  80134780    Movie    Norm Macdonald: Hitler's Dog, Gossip & Trickery
# 162   81132439    Movie                                     Travel Mates 2
# 2584  81035876    Movie                                           Reaction
# ...        ...      ...                                                ...
# 2196  80201604    Movie                                             Haapus
# 5523  80148180    Movie          Gringo: The Dangerous Life of John McAfee
# 386   70074559    Movie  Naruto the Movie: Ninja Clash in the Land of Snow
# 280   80198046    Movie                             Ghost of the Mountains
# 4591  80158871    Movie                            Judd Apatow: The Return
#
# ...

# %%
netflix[(netflix['IMDB rating']>8) & (netflix['country']=='Spain')]
# Out:
#        show_id     type                              title  \
# 5     80163890  TV Show                            Apaches
# 535   81062582  TV Show                   Nailed It! Spain
# 754   80134526    Movie                        Bomb Scared
# 977   80092849    Movie                       My Big Night
# 1298  80122177    Movie                          The Giant
# 1873  80233962    Movie                            Toc Toc
# 2377  80132381    Movie                     Something Huge
# 2425  80092850    Movie                  It's Now or Never
# 2440  80121387    Movie                    Elisa & Marcela
# 2640  80213115  TV Show               The Alcàsser Murders
# 2765  80103623    Movie                 The Heroes of Evil
# 2782  81001804    Movie               100 Days Of Solitude
# 2840  80173485    Movie                                Boi
# 2876  80232989    Movie                        The Warning
# 2935  80232891    Movie                  Camarón: The Film
# ...

# %%
netflix[netflix.isnull().any(axis=1)]
# Out:
#        show_id     type                                        title director  \
# 1     80117401    Movie                   Jandino: Whatever it Takes      NaN
# 2     70234439  TV Show                           Transformers Prime      NaN
# 3     80058654  TV Show             Transformers: Robots in Disguise      NaN
# 5     80163890  TV Show                                      Apaches      NaN
# 8     80117902  TV Show                                 Fire Chasers      NaN
# ...        ...      ...                                          ...      ...
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
# ...

# %%
netflix.dropna()
# Out:
#        show_id     type                                    title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 4     80125979    Movie                             #realityhigh
# 6     70304989    Movie                                 Automata
# 7     80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990    Movie                              Good People
# ...        ...      ...                                      ...
# 6142  80063224  TV Show            The Great British Baking Show
# 6158  80164216  TV Show  Miraculous: Tales of Ladybug & Cat Noir
# 6167  80115328  TV Show                             Sacred Games
# 6182  80176842  TV Show                         Men on a Mission
# 6213  80126599  TV Show                         Leyla and Mecnun
#
#                                   director  \
# 0                 Richard Finn, Tim Maltby
# 4                         Fernando Lebrija
# 6                              Gabe Ibáñez
# ...

# %%
netflix.fillna(value='Not available')
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                Not available
# 2                Not available
# ...

# %%
netflix.pivot('show_id','type','duration')
# Out:
# C:\Users\VENGATESH\AppData\Local\Temp\ipykernel_22068\2830425606.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   netflix.pivot('show_id','type','duration')
# type        Movie    TV Show
# show_id
# 247747    172 min        NaN
# 269880    119 min        NaN
# 281550    109 min        NaN
# 284890    166 min        NaN
# 292118     81 min        NaN
# ...           ...        ...
# 81224868      NaN  2 Seasons
# 81227195  107 min        NaN
# 81228864  102 min        NaN
# 81235603      NaN   1 Season
# 81235729   86 min        NaN
#
# [6234 rows x 2 columns]

# %% [markdown]
# # GroupBy

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_groupby.csv')
df
# Out:
#     value1  value2        day  color     name
# 0       12      15     monday    red     berk
# 1        4      16    tuesday    red  theresa
# 2        9      25  wednesday    red     john
# 3       15      65     monday  black    alina
# 4       23      55    tuesday  black    david
# 5       22      39  wednesday  black     mike
# 6       16      18     monday   blue     berk
# 7        8      47    tuesday   blue  theresa
# 8       62      64  wednesday   blue     john
# 9       19      81     monday  green    alina
# 10      21      92    tuesday  green    david
# 11      56      76  wednesday  green     mike

# %%
df.groupby(['color','name']).sum()
# Out:
# C:\Users\VENGATESH\AppData\Local\Temp\ipykernel_14372\2591786420.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['color','name']).sum()
#                value1  value2
# color name
# black alina        15      65
#       david        23      55
#       mike         22      39
# blue  berk         16      18
#       john         62      64
#       theresa       8      47
# green alina        19      81
#       david        21      92
#       mike         56      76
# red   berk         12      15
#       john          9      25
#       theresa       4      16

# %%
df.groupby('color').sum()
# Out:
# C:\Users\VENGATESH\AppData\Local\Temp\ipykernel_14372\2256032770.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('color').sum()
#        value1  value2
# color
# black      60     159
# blue       86     129
# green      96     249
# red        25      56

# %%
df.groupby('color').mean()
# Out:
# C:\Users\VENGATESH\AppData\Local\Temp\ipykernel_14372\2305194642.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('color').mean()
#           value1     value2
# color
# black  20.000000  53.000000
# blue   28.666667  43.000000
# green  32.000000  83.000000
# red     8.333333  18.666667

# %%
df.groupby(['color','name']).describe()
# Out:
#               value1                                         value2            \
#                count  mean std   min   25%   50%   75%   max  count  mean std
# color name
# black alina      1.0  15.0 NaN  15.0  15.0  15.0  15.0  15.0    1.0  65.0 NaN
#       david      1.0  23.0 NaN  23.0  23.0  23.0  23.0  23.0    1.0  55.0 NaN
#       mike       1.0  22.0 NaN  22.0  22.0  22.0  22.0  22.0    1.0  39.0 NaN
# blue  berk       1.0  16.0 NaN  16.0  16.0  16.0  16.0  16.0    1.0  18.0 NaN
#       john       1.0  62.0 NaN  62.0  62.0  62.0  62.0  62.0    1.0  64.0 NaN
#       theresa    1.0   8.0 NaN   8.0   8.0   8.0   8.0   8.0    1.0  47.0 NaN
# green alina      1.0  19.0 NaN  19.0  19.0  19.0  19.0  19.0    1.0  81.0 NaN
#       david      1.0  21.0 NaN  21.0  21.0  21.0  21.0  21.0    1.0  92.0 NaN
#       mike       1.0  56.0 NaN  56.0  56.0  56.0  56.0  56.0    1.0  76.0 NaN
# red   berk       1.0  12.0 NaN  12.0  12.0  12.0  12.0  12.0    1.0  15.0 NaN
# ...

# %%
for item in df.groupby('color'):
    print(item)
# Out:
# ('black',    value1  value2        day  color   name
# 3      15      65     monday  black  alina
# 4      23      55    tuesday  black  david
# 5      22      39  wednesday  black   mike)
# ('blue',    value1  value2        day color     name
# 6      16      18     monday  blue     berk
# 7       8      47    tuesday  blue  theresa
# 8      62      64  wednesday  blue     john)
# ('green',     value1  value2        day  color   name
# 9       19      81     monday  green  alina
# 10      21      92    tuesday  green  david
# 11      56      76  wednesday  green   mike)
# ('red',    value1  value2        day color     name
# 0      12      15     monday   red     berk
# 1       4      16    tuesday   red  theresa
# 2       9      25  wednesday   red     john)

# %%
for group_name,group in df.groupby('color'):
    print('Group %s:' %group_name)
    print(group)
    print('\n')
# Out:
# Group black:
#    value1  value2        day  color   name
# 3      15      65     monday  black  alina
# 4      23      55    tuesday  black  david
# 5      22      39  wednesday  black   mike
#
#
# Group blue:
#    value1  value2        day color     name
# 6      16      18     monday  blue     berk
# 7       8      47    tuesday  blue  theresa
# 8      62      64  wednesday  blue     john
#
#
# Group green:
#     value1  value2        day  color   name
# 9       19      81     monday  green  alina
# 10      21      92    tuesday  green  david
# 11      56      76  wednesday  green   mike
#
#
# Group red:
#    value1  value2        day color     name
# 0      12      15     monday   red     berk
# 1       4      16    tuesday   red  theresa
# 2       9      25  wednesday   red     john
