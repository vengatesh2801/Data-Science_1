# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('water_usage.csv')
data
# Out:
#    Unnamed: 0           Usage  Percentage
# 0           0            Leak          12
# 1           1  Clothes Washer          17
# 2           2          Faucet          19
# 3           3          Shower          20
# 4           4          Toilet          24
# 5           5           Other           8

# %%
y = data['Percentage']
y
# Out:
# 0    12
# 1    17
# 2    19
# 3    20
# 4    24
# 5     8
# Name: Percentage, dtype: int64

# %%
plt.pie(y, labels = data['Usage'])
# Out:
# ([<matplotlib.patches.Wedge at 0x290019ed2a0>,
# ...
#  [Text(1.022754137889241, 0.404936999335002, 'Leak'),
#   Text(0.30689022851116454, 1.056323050796661, 'Clothes Washer'),
#   Text(-0.8251221670583667, 0.7274430626715089, 'Faucet'),
#   Text(-0.9639373540021144, -0.5299290306818474, 'Shower'),
#   Text(0.3399186742226881, -1.0461621742897658, 'Toilet'),
#   Text(1.065441465972024, -0.27355891977302593, 'Other')])

# %%
data.iplot(kind='pie', labels ='Usage',values='Percentage',title='Water usage',
                  hoverinfo="label+percent+name")
# Out:
# <div>                            <div id="5f400ba2-decb-4fd6-acb5-ce852ad768da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
flight = pd.read_csv('flight_details.csv')
flight
# Out:
#      Years     Months  Passengers
# 0     1949    January         112
# 1     1949   February         118
# 2     1949      March         132
# 3     1949      April         129
# 4     1949        May         121
# ..     ...        ...         ...
# 139   1960     August         606
# 140   1960  September         508
# 141   1960    October         461
# 142   1960   November         390
# 143   1960   December         432
#
# [144 rows x 3 columns]

# %%
scores = pd.read_csv('iq_scores.csv')
scores
# Out:
#     group_a  group_b  group_c  group_d
# 0       118      126      108       93
# 1       103       89       89       99
# 2       125       90      114       91
# 3       107      101      116      110
# 4       111      102      126       80
# ..      ...      ...      ...      ...
# 95       88       91      102      105
# 96      122      112       69       74
# 97      125      102       96       85
# 98       93      112      101       85
# 99       78       75       90       95
#
# [100 rows x 4 columns]

# %%
sns.violinplot(data=scores.head())
# Out:
# <Axes: >

# %%
sns.boxplot(data=scores)
# Out:
# <Axes: >

# %%
animals=pd.read_csv('anage_data.csv')
animals
# Out:
#       Unnamed: 0  HAGRID   Kingdom      Phylum                  Class  \
# 0              0       3  Animalia  Arthropoda           Branchiopoda
# 1              1       5  Animalia  Arthropoda                Insecta
# 2              2       6  Animalia  Arthropoda                Insecta
# 3              3       8  Animalia  Arthropoda                Insecta
# 4              4       9  Animalia  Arthropoda                Insecta
# ...          ...     ...       ...         ...                    ...
# 4213        4214    4239  Animalia    Porifera         Hexactinellida
# 4214        4215    4241   Plantae   Pinophyta              Pinopsida
# 4215        4216    4242     Fungi  Ascomycota        Saccharomycetes
# 4216        4217    4243     Fungi  Ascomycota  Schizosaccharomycetes
# 4217        4218    4244     Fungi  Ascomycota        Sordariomycetes
#
#                         Order                    Family                Genus  \
# ...

# %%
animals.groupby(['Body mass (g)','Maximum longevity (yrs)']).max()
# Out:
#                                        Unnamed: 0  HAGRID   Kingdom    Phylum  \
# Body mass (g) Maximum longevity (yrs)
# 0.76          25.0                            142     149  Animalia  Chordata
# 2.40          3.2                            2850    2867  Animalia  Chordata
# 3.00          7.0                             329     337  Animalia  Chordata
# 3.20          9.1                             318     326  Animalia  Chordata
# 3.21          25.0                            110     117  Animalia  Chordata
# ...                                           ...     ...       ...       ...
# 196500.00     24.3                           1579    1591  Animalia  Chordata
# 347000.00     20.0                           1552    1564  Animalia  Chordata
# 407000.00     28.4                           1647    1659  Animalia  Chordata
# 450000.00     69.0                           2824    2841  Animalia  Chordata
# ...

# %%
sns.scatterplot(x='Body mass (g)', y='Maximum longevity (yrs)',data=animals.groupby(['Body mass (g)','Maximum longevity (yrs)']).max(),hue='Class')
# Out:
# <Axes: xlabel='Body mass (g)', ylabel='Maximum longevity (yrs)'>
