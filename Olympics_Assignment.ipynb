# %% [markdown]
# # 1. Import the necessary libraries

# %% [markdown]
# # 2. Import the Olypics dataset

# %% [markdown]
# # 3. Assign it to a variable called odata.

# %%
import pandas as pd
import numpy as np

odata = pd.read_csv('olympics-Copy1.csv')
odata
# Out:
#       List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event  \
# 0                                                    NaN
# 1      DISCLAIMER: The IOC Research and Reference Ser...
# 2                                                    NaN
# 3                                                   City
# 4                                                 Athens
# ...                                                  ...
# 29215                                            Beijing
# 29216                                            Beijing
# 29217                                            Beijing
# 29218                                            Beijing
# 29219                                            Beijing
#
#       Unnamed: 1 Unnamed: 2       Unnamed: 3            Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN              NaN                   NaN        NaN
# ...

# %% [markdown]
# # 4. show the first 5 entries

# %%
odata.head()
# Out:
#   List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event  \
# 0                                                NaN
# 1  DISCLAIMER: The IOC Research and Reference Ser...
# 2                                                NaN
# 3                                               City
# 4                                             Athens
#
#   Unnamed: 1 Unnamed: 2  Unnamed: 3     Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN         NaN            NaN        NaN        NaN
# 1        NaN        NaN         NaN            NaN        NaN        NaN
# 2        NaN        NaN         NaN            NaN        NaN        NaN
# 3    Edition      Sport  Discipline        Athlete        NOC     Gender
# 4       1896   Aquatics    Swimming  HAJOS, Alfred        HUN        Men
#
#        Unnamed: 7    Unnamed: 8 Unnamed: 9
# 0             NaN           NaN        NaN
# 1             NaN           NaN        NaN
# ...

# %%
5. What is the number of observations in the dataset?

# %% [markdown]
# # 6. What is the number of columns in the dataset?

# %%
10 columns

# %% [markdown]
# # 7. Print the name of all the columns.

# %%
odata.columns
# Out:
# Index(['List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
# # 8. How is the dataset indexed?

# %%
odata.index
# Out:
# RangeIndex(start=0, stop=29220, step=1)

# %% [markdown]
# # 9. Rename the column as Available_City to City, Edition_year to Edition , Sport_name to Sport

# %%
odata.replace('Unnamed: 1','Available_City to City',in)
# Out:
#       List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event  \
# 0                                                    NaN
# 1      DISCLAIMER: The IOC Research and Reference Ser...
# 2                                                    NaN
# 3                                                   City
# 4                                                 Athens
# ...                                                  ...
# 29215                                            Beijing
# 29216                                            Beijing
# 29217                                            Beijing
# 29218                                            Beijing
# 29219                                            Beijing
#
#       Unnamed: 1 Unnamed: 2       Unnamed: 3            Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN              NaN                   NaN        NaN
# ...

# %%
odata.shape
# Out:
# (29220, 10)

# %%
odata.rename(columns={'List of medallists at the Games of the Olympiad per edition, sport, discipline, gender and event':'City','Unnamed: 1':'Year','Unnamed: 2':'Sport','Unnamed: 3':'Discipline','Unnamed: 4':'Athelete','Unnamed: 5':'NOC','Unnamed: 6':'Gender','Unnamed: 7':'Event','Unnamed: 8':'Sex','Unnamed: 9':'Medal'},inplace=True)

odata
# Out:
#                                                     City     Year      Sport  \
# 0                                                    NaN      NaN        NaN
# 1      DISCLAIMER: The IOC Research and Reference Ser...      NaN        NaN
# 2                                                    NaN      NaN        NaN
# 3                                                   City  Edition      Sport
# 4                                                 Athens     1896   Aquatics
# ...                                                  ...      ...        ...
# 29215                                            Beijing     2008  Wrestling
# 29216                                            Beijing     2008  Wrestling
# 29217                                            Beijing     2008  Wrestling
# 29218                                            Beijing     2008  Wrestling
# 29219                                            Beijing     2008  Wrestling
#
# ...

# %% [markdown]
# # 10. How many Athletes own the Gold medal?

# %%
odata[odata['Medal']=='Gold']
# Out:
#           City  Year      Sport       Discipline             Athelete  NOC  \
# 4       Athens  1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 7       Athens  1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 10      Athens  1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 13      Athens  1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 17      Athens  1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...   ...        ...              ...                  ...  ...
# 29203  Beijing  2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29207  Beijing  2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29210  Beijing  2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29214  Beijing  2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29218  Beijing  2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
#       Gender                       Event Sex Medal
# ...

# %% [markdown]
# # 11. Display the male gold medal winners for the 100m Track?

# %%
odata[(odata['Medal']=='Gold') & (odata['Gender']=='Men') & (odata['Event']=='100m freestyle')]
# Out:
#                         City  Year     Sport Discipline  \
# 4                     Athens  1896  Aquatics   Swimming
# 678                 St Louis  1904  Aquatics   Swimming
# 1148                  London  1908  Aquatics   Swimming
# 1957               Stockholm  1912  Aquatics   Swimming
# 2845                 Antwerp  1920  Aquatics   Swimming
# 4146                   Paris  1924  Aquatics   Swimming
# 5027               Amsterdam  1928  Aquatics   Swimming
# 5737             Los Angeles  1932  Aquatics   Swimming
# 6352                  Berlin  1936  Aquatics   Swimming
# 7227                  London  1948  Aquatics   Swimming
# 8041                Helsinki  1952  Aquatics   Swimming
# 8933   Melbourne / Stockholm  1956  Aquatics   Swimming
# 9818                    Rome  1960  Aquatics   Swimming
# 10697                  Tokyo  1964  Aquatics   Swimming
# 11719                 Mexico  1968  Aquatics   Swimming
# 12750                 Munich  1972  Aquatics   Swimming
# ...

# %% [markdown]
# # 12. Which three countries have won the most medals in recent years (from 1984 to 2008)?

# %%
odata[(odata['Year']> '1984')&(odata['Year']< '2008')&(odata['Medal']=='Gold')&{odata['City'].max}]
# Out:
#          City  Year      Sport       Discipline                  Athelete  \
# 18056   Seoul  1988   Aquatics           Diving         LOUGANIS, Gregory
# 18059   Seoul  1988   Aquatics           Diving               XU, Yan-Mei
# 18062   Seoul  1988   Aquatics           Diving         LOUGANIS, Gregory
# 18065   Seoul  1988   Aquatics           Diving                  GAO, Min
# 18068   Seoul  1988   Aquatics         Swimming            SUZUKI, Daichi
# ...       ...   ...        ...              ...                       ...
# 27164  Athens  2004  Wrestling  Wrestling Gre-R           MANSUROV, Farid
# 27167  Athens  2004  Wrestling  Wrestling Gre-R  DOKTURISHIVILI, Alexandr
# 27170  Athens  2004  Wrestling  Wrestling Gre-R           MICHINE, Alexei
# 27173  Athens  2004  Wrestling  Wrestling Gre-R      GABER IBRAHIM, Karam
# 27176  Athens  2004  Wrestling  Wrestling Gre-R            BAROEV, Khasan
#
#        NOC Gender            Event Sex Medal
# ...

# %% [markdown]
# # 14. Display the women gold medal winners for the 100m Track?

# %%
odata[(odata['Medal']=='Gold') & (odata['Gender']=='Women') & (odata['Event']=='100m freestyle')]
# Out:
#                         City  Year     Sport Discipline  \
# 1960               Stockholm  1912  Aquatics   Swimming
# 2848                 Antwerp  1920  Aquatics   Swimming
# 4149                   Paris  1924  Aquatics   Swimming
# 5030               Amsterdam  1928  Aquatics   Swimming
# 5740             Los Angeles  1932  Aquatics   Swimming
# 6355                  Berlin  1936  Aquatics   Swimming
# 7230                  London  1948  Aquatics   Swimming
# 8044                Helsinki  1952  Aquatics   Swimming
# 8936   Melbourne / Stockholm  1956  Aquatics   Swimming
# 9821                    Rome  1960  Aquatics   Swimming
# 10700                  Tokyo  1964  Aquatics   Swimming
# 11722                 Mexico  1968  Aquatics   Swimming
# 12753                 Munich  1972  Aquatics   Swimming
# 13938               Montreal  1976  Aquatics   Swimming
# 15243                 Moscow  1980  Aquatics   Swimming
# 16630            Los Angeles  1984  Aquatics   Swimming
# ...

# %% [markdown]
# # 15. list out the Sliver medal winner @ year 2008?

# %%
odata[(odata['Medal']=='Silver')& (odata['Year']=='2008')]
# Out:
#           City  Year      Sport       Discipline             Athelete  NOC  \
# 27180  Beijing  2008   Aquatics           Diving          ZHOU, Luxin  CHN
# 27183  Beijing  2008   Aquatics           Diving      HEYMANS, Emilie  CAN
# 27186  Beijing  2008   Aquatics           Diving  DESPATIE, Alexandre  CAN
# 27189  Beijing  2008   Aquatics           Diving     PAKHALINA, Julia  RUS
# 27194  Beijing  2008   Aquatics           Diving    HAUSDING, Patrick  GER
# ...        ...   ...        ...              ...                  ...  ...
# 29204  Beijing  2008  Wrestling  Wrestling Gre-R   BEGALIEV, Kanatbek  KGZ
# 29208  Beijing  2008  Wrestling  Wrestling Gre-R     CHANG, Yongxiang  CHN
# 29211  Beijing  2008  Wrestling  Wrestling Gre-R        FODOR, Zoltan  HUN
# 29215  Beijing  2008  Wrestling  Wrestling Gre-R       ENGLICH, Mirko  GER
# 29219  Beijing  2008  Wrestling  Wrestling Gre-R       BAROEV, Khasan  RUS
#
#       Gender                             Event Sex   Medal
# ...

# %% [markdown]
# # 16.Group by Countries and apply aggregate function min,max,count on over the year

# %%
odata.groupby(['City','Year']).describe()
# Out:
#                               Sport                         Discipline         \
#                               count unique         top freq      count unique
# City                  Year
# Amsterdam             1928      710     14   Athletics  108        710     20
# Antwerp               1920     1298     22  Gymnastics  202       1298     29
# Athens                1896      151      9  Gymnastics   45        151     10
#                       2004     1998     28    Aquatics  332       1998     40
# Atlanta               1996     1859     26    Aquatics  262       1859     37
# Barcelona             1992     1705     25    Aquatics  228       1705     34
# Beijing               2008     2042     28    Aquatics  347       2042     41
# Berlin                1936      875     19   Athletics  114        875     25
# City                  Edition     1      1       Sport    1          1      1
# Helsinki              1952      889     17   Athletics  126        889     23
# ...
